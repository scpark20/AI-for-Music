# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

from torch.utils.data import DataLoader
from dataset import dataset_hparams, MaestroDataset
from model import model_hparams, Model

# %%
maestro_dataset = MaestroDataset(dataset_hparams)
print(maestro_dataset)

train_loader = DataLoader(maestro_dataset, batch_size=16)
print(train_loader)
# Out:
# <dataset.MaestroDataset object at 0x7facf8330ee0>
# <torch.utils.data.dataloader.DataLoader object at 0x7facf8330dc0>

# %%
maestro_dataset[0]
# Out:
# array([  8, 327,   0, 336,   1, 339,   0, 110, 197,   0, 112, 209,   0,
#        113, 212,   8, 337,   1, 340,   0, 112, 200,   1, 325,   8, 328,
#          0, 114, 204,   0, 116, 207,   0, 112, 202,  10, 330,   0, 113,
#        200,   7, 332,   2, 328,   1, 115, 209,   0, 110, 199,   0, 110,
#        206,   0, 335,   8, 327,   1, 108, 197,   6, 337,   1, 334,   0,
#        110, 207,   0, 111, 211,   1, 325,   0, 110, 195,   2, 335,   6,
#        339,   2, 110, 209,   0, 108, 202,   0, 108, 206,   3, 323,   3,
#        334,   2, 330,   0, 337,   1, 111, 204,   0, 115, 212,   0, 111,
#        207,   4, 335,   2, 340,   2, 115, 206,   0, 116, 211,   0, 113,
#        202,   0, 332,   1, 339,   1, 334,   5, 119, 209,   0, 115, 200,
#          0, 113, 204,   0, 330,   2, 328,   1, 332,   2, 337,   2, 118,
#        207,   0, 113, 199,   0, 115, 202,   2, 330,   0, 335,   3, 327,
#          2, 117, 206,   0, 115, 200,   0, 113, 197,   7, 334,   0, 328,
#          0, 325,   0, 116, 204,   0, 114, 195,   0, 114, 199,   2, 332,
#          0, 327,   0, 323,   6, 115, 202,   0, 111, 194,   0, 110, 197,
#          4, 322,   5, 112, 193,   2, 321,   9, 113, 201,   0, 330,   0,
#        110, 195,   0, 110, 192,   2, 325,   8, 320,   1, 112, 191,   3,
#        319,   1, 323,  16, 329,   0, 111, 200,   0, 108, 194,   0, 109,
#        190,  34, 322,   1, 318,   4, 328,  72, 107, 178,   5, 306,   9,
#        109, 183,  11, 110, 195,  10, 323,   0, 114, 199,   9, 327,   0,
#        114, 195,  11, 323,   0, 113, 200,   5, 311,   3, 328,   1, 112,
#        190,   0, 110, 182,   2, 318,   0, 310,   7, 113, 188,  11, 114,
#        202,   9, 330,   1, 117, 206,  10, 119, 202,   0, 334,  10, 120,
#        207,   1, 330,   5, 316,   2, 117, 187,   0, 335,   0, 119, 195,
#          2, 315,   0, 323,   6, 118, 193,  11, 118, 207,   9, 335,   1,
#        117, 211,   9, 339,   0, 116, 207,   9, 335,   1, 115, 212,   7,
#        340,   1, 321,   0, 113, 192,   0, 112, 200,   1, 320,   0, 328,
#          9, 113, 213,   9, 341,   0, 112, 195,   0, 111, 201,   1, 107,
#        197,   0, 329,   0, 323,   1, 325,   6, 118, 214,   7, 342,   2,
#        114, 202,   0, 114, 197,   0, 112, 194,   1, 325,   0, 322,   0,
#        330,   8, 120, 215,  10, 116, 199,   0, 343,   0, 114, 197,   0,
#        118, 203,   1, 325,   0, 327,   0, 331,   8, 124, 216,   9, 344,
#          0, 120, 204,   0, 116, 195,   0, 117, 199,   1, 327,   0, 323,
#          0, 332,   8, 124, 218,   9, 346,   0, 118, 200,   0, 122, 206,
#          0, 119, 202,   2, 330,   0, 328,   0, 334,   9, 125, 219,   1,
#        113, 217,   1, 345,   5, 347,   1, 122, 207,   0, 117, 202,   0,
#        117, 199,   1, 330,   0, 335,   0, 327,  56, 111, 192,   2, 320,
#          9, 114, 204,  10, 110, 176,  10, 304,   0, 114, 188,   9, 316,
#          0, 114, 185,  10, 313,   0])

# %%
def tokens_to_event_list(tokens, hp):
    current_time = 0
    current_velocity = 0
    event_list = []
    for token in tokens:
        # interval
        if token < hp.offsets.velocity:
            current_time += token / hp.dims.interval * hp.max_note_duration
            
        # velocity
        elif token < hp.offsets.note_on:
            current_velocity = (token - hp.offsets.velocity) / hp.dims.velocity * 128
            
        # note_on
        elif token < hp.offsets.note_off:
            event = {'time': current_time,
                     'type': 'note_on',
                     'note': token - hp.offsets.note_on,
                     'velocity': int(current_velocity)}
            event_list.append(event)
                     
        # note_off
        elif token < hp.offsets.pedal_on:
            event = {'time': current_time,
                     'type': 'note_off',
                     'note': token - hp.offsets.note_off}
            event_list.append(event)
            
        # pedal_on
        elif token < hp.offsets.pedal_off:
            event = {'time': current_time,
                     'type': 'pedal_on'}
            event_list.append(event)
            
        # pedal_off
        else:
            event = {'time': current_time,
                     'type': 'pedal_off'}
            event_list.append(event)
    
    return event_list

# %%
def save_event_list_to_midi_file(event_list, midi_file):
    from midiutil import MIDIFile
    '''
    Reference : https://midiutil.readthedocs.io/en/1.2.1/index.html
    '''
    track    = 0
    channel  = 0
    tempo    = 60  # In BPM
    MyMIDI = MIDIFile(1) # One track, defaults to format 1 (tempo track
                         # automatically created)
    MyMIDI.addTempo(track, 0, tempo)
    
    notes = [None for _ in range(128)]
    for event in event_list:
        if event['type'] == 'note_on':
            notes[event['note']] = event
            
        elif event['type'] == 'note_off' and notes[event['note']] is not None:
            pitch = event['note']
            start_time = notes[event['note']]['time']
            duration = max(event['time'] - start_time, 0)
            velocity = notes[event['note']]['velocity']
            MyMIDI.addNote(track, channel, pitch, start_time, duration, velocity)
            notes[event['note']] = None
            
        elif event['type'] == 'pedal_on':
            MyMIDI.addControllerEvent(track, channel, event['time'], 64, 1)
            
        elif event['type'] == 'pedal_off':
            MyMIDI.addControllerEvent(track, channel, event['time'], 64, 0)
            
    with open(midi_file, "wb") as output_file:
        MyMIDI.writeFile(output_file)

# %%
event_list = tokens_to_event_list(maestro_dataset[0], dataset_hparams)
for event in event_list:
    print(event)
# Out:
# {'time': 0.0, 'type': 'note_off', 'note': 70}
# {'time': 0.0, 'type': 'note_off', 'note': 77}
# {'time': 0.0, 'type': 'note_off', 'note': 62}
# {'time': 0.02, 'type': 'note_off', 'note': 74}
# {'time': 0.08, 'type': 'note_off', 'note': 58}
# {'time': 0.38, 'type': 'note_on', 'note': 79, 'velocity': 72}
# {'time': 0.46, 'type': 'note_off', 'note': 79}
# {'time': 0.46, 'type': 'note_on', 'note': 77, 'velocity': 84}
# {'time': 0.56, 'type': 'note_on', 'note': 75, 'velocity': 76}
# {'time': 0.56, 'type': 'note_off', 'note': 77}
# {'time': 0.64, 'type': 'note_on', 'note': 74, 'velocity': 76}
# {'time': 0.64, 'type': 'note_off', 'note': 75}
# {'time': 0.7, 'type': 'note_off', 'note': 74}
# {'time': 0.72, 'type': 'note_on', 'note': 72, 'velocity': 72}
# {'time': 0.74, 'type': 'pedal_off'}
# {'time': 0.78, 'type': 'note_off', 'note': 72}
# {'time': 0.78, 'type': 'note_on', 'note': 70, 'velocity': 76}
# {'time': 0.86, 'type': 'note_off', 'note': 70}
# {'time': 0.86, 'type': 'note_on', 'note': 69, 'velocity': 80}
# {'time': 0.86, 'type': 'note_on', 'note': 53, 'velocity': 52}
# {'time': 0.86, 'type': 'note_on', 'note': 60, 'velocity': 52}
# {'time': 0.86, 'type': 'note_on', 'note': 63, 'velocity': 52}
# {'time': 1.02, 'type': 'pedal_on'}
# {'time': 1.06, 'type': 'note_off', 'note': 53}
# {'time': 1.1400000000000001, 'type': 'note_off', 'note': 63}
# {'time': 1.1400000000000001, 'type': 'note_off', 'note': 60}
# {'time': 1.4000000000000001, 'type': 'note_off', 'note': 69}
# {'time': 1.4000000000000001, 'type': 'note_on', 'note': 74, 'velocity': 56}
# {'time': 1.4400000000000002, 'type': 'note_off', 'note': 74}
# {'time': 1.4600000000000002, 'type': 'note_on', 'note': 72, 'velocity': 60}
# {'time': 1.5000000000000002, 'type': 'note_off', 'note': 72}
# {'time': 1.5000000000000002, 'type': 'note_on', 'note': 71, 'velocity': 64}
# {'time': 1.5600000000000003, 'type': 'note_off', 'note': 71}
# {'time': 1.5600000000000003, 'type': 'note_on', 'note': 72, 'velocity': 72}
# {'time': 1.6600000000000004, 'type': 'note_off', 'note': 72}
# {'time': 1.6800000000000004, 'type': 'note_on', 'note': 75, 'velocity': 72}
# {'time': 1.7000000000000004, 'type': 'pedal_off'}
# {'time': 1.9200000000000004, 'type': 'note_off', 'note': 75}
# {'time': 1.9200000000000004, 'type': 'note_on', 'note': 69, 'velocity': 60}
# {'time': 2.1200000000000006, 'type': 'note_off', 'note': 69}
# {'time': 2.1200000000000006, 'type': 'note_on', 'note': 70, 'velocity': 56}
# {'time': 2.1200000000000006, 'type': 'note_on', 'note': 58, 'velocity': 40}
# {'time': 2.3200000000000007, 'type': 'note_on', 'note': 65, 'velocity': 48}
# {'time': 2.3400000000000007, 'type': 'note_on', 'note': 62, 'velocity': 40}
# {'time': 2.480000000000001, 'type': 'note_off', 'note': 65}
# {'time': 2.520000000000001, 'type': 'note_on', 'note': 66, 'velocity': 56}
# {'time': 2.520000000000001, 'type': 'note_on', 'note': 63, 'velocity': 48}
# {'time': 2.520000000000001, 'type': 'note_off', 'note': 62}
# {'time': 2.660000000000001, 'type': 'note_off', 'note': 63}
# {'time': 2.680000000000001, 'type': 'note_off', 'note': 66}
# {'time': 2.700000000000001, 'type': 'note_on', 'note': 64, 'velocity': 48}
# {'time': 2.700000000000001, 'type': 'note_on', 'note': 67, 'velocity': 60}
# {'time': 2.8800000000000012, 'type': 'note_off', 'note': 64}
# {'time': 2.8800000000000012, 'type': 'note_off', 'note': 67}
# {'time': 2.9000000000000012, 'type': 'note_on', 'note': 65, 'velocity': 44}
# {'time': 2.9000000000000012, 'type': 'note_on', 'note': 68, 'velocity': 56}
# {'time': 2.9600000000000013, 'type': 'note_off', 'note': 70}
# {'time': 3.0600000000000014, 'type': 'note_off', 'note': 65}
# {'time': 3.0600000000000014, 'type': 'note_off', 'note': 68}
# {'time': 3.0600000000000014, 'type': 'note_on', 'note': 66, 'velocity': 40}
# {'time': 3.0600000000000014, 'type': 'note_on', 'note': 69, 'velocity': 60}
# {'time': 3.2200000000000015, 'type': 'note_off', 'note': 66}
# {'time': 3.2400000000000015, 'type': 'note_off', 'note': 69}
# {'time': 3.2400000000000015, 'type': 'note_on', 'note': 67, 'velocity': 48}
# {'time': 3.2400000000000015, 'type': 'note_on', 'note': 70, 'velocity': 56}
# {'time': 3.4200000000000017, 'type': 'note_off', 'note': 70}
# {'time': 3.4200000000000017, 'type': 'note_off', 'note': 67}
# {'time': 3.4200000000000017, 'type': 'note_on', 'note': 71, 'velocity': 56}
# {'time': 3.4200000000000017, 'type': 'note_on', 'note': 65, 'velocity': 40}
# {'time': 3.600000000000002, 'type': 'note_off', 'note': 65}
# {'time': 3.600000000000002, 'type': 'note_on', 'note': 72, 'velocity': 56}
# {'time': 3.600000000000002, 'type': 'note_on', 'note': 63, 'velocity': 48}
# {'time': 3.640000000000002, 'type': 'note_off', 'note': 71}
# {'time': 3.760000000000002, 'type': 'note_off', 'note': 63}
# {'time': 3.760000000000002, 'type': 'note_off', 'note': 72}
# {'time': 3.760000000000002, 'type': 'note_on', 'note': 74, 'velocity': 60}
# {'time': 3.760000000000002, 'type': 'note_on', 'note': 62, 'velocity': 40}
# {'time': 3.920000000000002, 'type': 'note_off', 'note': 62}
# {'time': 3.960000000000002, 'type': 'note_on', 'note': 60, 'velocity': 44}
# {'time': 3.960000000000002, 'type': 'note_on', 'note': 75, 'velocity': 56}
# {'time': 3.960000000000002, 'type': 'note_off', 'note': 74}
# {'time': 4.100000000000002, 'type': 'note_off', 'note': 75}
# {'time': 4.140000000000002, 'type': 'note_off', 'note': 60}
# {'time': 4.140000000000002, 'type': 'note_on', 'note': 69, 'velocity': 48}
# {'time': 4.140000000000002, 'type': 'note_on', 'note': 63, 'velocity': 40}
# {'time': 4.3400000000000025, 'type': 'pedal_on'}
# {'time': 4.3400000000000025, 'type': 'note_off', 'note': 63}
# {'time': 4.3400000000000025, 'type': 'note_on', 'note': 62, 'velocity': 32}
# {'time': 4.3400000000000025, 'type': 'note_on', 'note': 70, 'velocity': 48}
# {'time': 4.3400000000000025, 'type': 'note_off', 'note': 69}
# {'time': 4.380000000000003, 'type': 'note_off', 'note': 70}
# {'time': 4.480000000000002, 'type': 'note_off', 'note': 62}
# {'time': 4.520000000000002, 'type': 'note_on', 'note': 77, 'velocity': 76}
# {'time': 4.520000000000002, 'type': 'note_on', 'note': 74, 'velocity': 64}
# {'time': 4.520000000000002, 'type': 'note_off', 'note': 58}
# {'time': 4.700000000000002, 'type': 'note_off', 'note': 77}
# {'time': 4.700000000000002, 'type': 'note_on', 'note': 79, 'velocity': 80}
# {'time': 4.700000000000002, 'type': 'note_on', 'note': 75, 'velocity': 76}
# {'time': 4.700000000000002, 'type': 'note_off', 'note': 74}
# {'time': 4.740000000000002, 'type': 'note_off', 'note': 75}
# {'time': 4.880000000000002, 'type': 'note_on', 'note': 77, 'velocity': 84}
# {'time': 4.880000000000002, 'type': 'note_on', 'note': 74, 'velocity': 72}
# {'time': 4.880000000000002, 'type': 'note_off', 'note': 79}
# {'time': 5.060000000000001, 'type': 'note_off', 'note': 77}
# {'time': 5.060000000000001, 'type': 'note_on', 'note': 75, 'velocity': 80}
# {'time': 5.060000000000001, 'type': 'note_on', 'note': 72, 'velocity': 76}
# {'time': 5.060000000000001, 'type': 'note_off', 'note': 74}
# {'time': 5.1400000000000015, 'type': 'note_off', 'note': 75}
# {'time': 5.240000000000001, 'type': 'note_off', 'note': 72}
# {'time': 5.240000000000001, 'type': 'note_on', 'note': 74, 'velocity': 80}
# {'time': 5.240000000000001, 'type': 'note_on', 'note': 70, 'velocity': 76}
# {'time': 5.400000000000001, 'type': 'note_off', 'note': 70}
# {'time': 5.420000000000001, 'type': 'note_off', 'note': 74}
# {'time': 5.44, 'type': 'note_on', 'note': 72, 'velocity': 76}
# {'time': 5.44, 'type': 'note_on', 'note': 69, 'velocity': 72}
# {'time': 5.44, 'type': 'note_on', 'note': 53, 'velocity': 84}
# {'time': 5.44, 'type': 'note_on', 'note': 41, 'velocity': 84}
# {'time': 5.46, 'type': 'note_off', 'note': 53}
# {'time': 5.46, 'type': 'note_off', 'note': 41}
# {'time': 5.62, 'type': 'note_on', 'note': 52, 'velocity': 84}
# {'time': 5.62, 'type': 'note_on', 'note': 40, 'velocity': 76}
# {'time': 5.64, 'type': 'note_off', 'note': 52}
# {'time': 5.64, 'type': 'note_off', 'note': 40}
# {'time': 5.76, 'type': 'note_off', 'note': 69}
# {'time': 5.76, 'type': 'note_off', 'note': 72}
# {'time': 5.779999999999999, 'type': 'note_on', 'note': 51, 'velocity': 88}
# {'time': 5.779999999999999, 'type': 'note_on', 'note': 39, 'velocity': 80}
# {'time': 5.799999999999999, 'type': 'note_off', 'note': 51}
# {'time': 5.799999999999999, 'type': 'note_off', 'note': 39}
# {'time': 5.939999999999999, 'type': 'note_on', 'note': 50, 'velocity': 84}
# {'time': 5.939999999999999, 'type': 'note_on', 'note': 38, 'velocity': 80}
# {'time': 5.959999999999998, 'type': 'note_off', 'note': 50}
# {'time': 5.959999999999998, 'type': 'note_off', 'note': 38}
# {'time': 6.099999999999998, 'type': 'note_on', 'note': 81, 'velocity': 88}
# {'time': 6.099999999999998, 'type': 'note_on', 'note': 75, 'velocity': 84}
# {'time': 6.099999999999998, 'type': 'note_on', 'note': 48, 'velocity': 88}
# {'time': 6.099999999999998, 'type': 'note_on', 'note': 72, 'velocity': 80}
# {'time': 6.099999999999998, 'type': 'note_on', 'note': 36, 'velocity': 80}
# {'time': 6.119999999999997, 'type': 'note_off', 'note': 75}
# {'time': 6.119999999999997, 'type': 'note_off', 'note': 72}
# {'time': 6.119999999999997, 'type': 'note_off', 'note': 48}
# {'time': 6.119999999999997, 'type': 'note_off', 'note': 36}
# {'time': 6.119999999999997, 'type': 'note_off', 'note': 81}
# {'time': 6.279999999999998, 'type': 'note_on', 'note': 53, 'velocity': 88}
# {'time': 6.279999999999998, 'type': 'note_on', 'note': 41, 'velocity': 88}
# {'time': 6.299999999999997, 'type': 'note_off', 'note': 53}
# {'time': 6.299999999999997, 'type': 'note_off', 'note': 41}
# {'time': 6.339999999999997, 'type': 'pedal_off'}
# {'time': 6.479999999999997, 'type': 'note_on', 'note': 82, 'velocity': 88}
# {'time': 6.479999999999997, 'type': 'note_on', 'note': 74, 'velocity': 92}
# {'time': 6.479999999999997, 'type': 'note_on', 'note': 46, 'velocity': 96}
# {'time': 6.479999999999997, 'type': 'note_on', 'note': 77, 'velocity': 88}
# {'time': 6.479999999999997, 'type': 'note_on', 'note': 34, 'velocity': 88}
# {'time': 6.4999999999999964, 'type': 'pedal_on'}
# {'time': 6.519999999999996, 'type': 'note_off', 'note': 46}
# {'time': 6.519999999999996, 'type': 'note_off', 'note': 74}
# {'time': 6.519999999999996, 'type': 'note_off', 'note': 34}
# {'time': 6.519999999999996, 'type': 'note_off', 'note': 82}
# {'time': 6.519999999999996, 'type': 'note_off', 'note': 77}
# {'time': 7.339999999999996, 'type': 'pedal_off'}
# {'time': 7.699999999999997, 'type': 'note_on', 'note': 65, 'velocity': 48}
# {'time': 7.699999999999997, 'type': 'note_on', 'note': 62, 'velocity': 40}
# {'time': 7.899999999999997, 'type': 'note_off', 'note': 65}
# {'time': 7.899999999999997, 'type': 'note_off', 'note': 62}
# {'time': 7.899999999999997, 'type': 'note_on', 'note': 67, 'velocity': 64}
# {'time': 7.899999999999997, 'type': 'note_on', 'note': 63, 'velocity': 40}
# {'time': 7.939999999999997, 'type': 'note_off', 'note': 63}
# {'time': 8.059999999999997, 'type': 'note_off', 'note': 67}
# {'time': 8.059999999999997, 'type': 'note_on', 'note': 62, 'velocity': 60}
# {'time': 8.059999999999997, 'type': 'note_on', 'note': 65, 'velocity': 64}
# {'time': 8.239999999999997, 'type': 'note_off', 'note': 65}
# {'time': 8.239999999999997, 'type': 'note_off', 'note': 62}
# {'time': 8.239999999999997, 'type': 'note_on', 'note': 63, 'velocity': 64}
# {'time': 8.239999999999997, 'type': 'note_on', 'note': 60, 'velocity': 56}
# {'time': 8.299999999999997, 'type': 'note_off', 'note': 63}
# {'time': 8.399999999999997, 'type': 'note_off', 'note': 60}
# {'time': 8.399999999999997, 'type': 'note_on', 'note': 62, 'velocity': 56}
# {'time': 8.399999999999997, 'type': 'note_on', 'note': 58, 'velocity': 56}
# {'time': 8.479999999999997, 'type': 'note_off', 'note': 58}
# {'time': 8.539999999999997, 'type': 'note_off', 'note': 62}
# {'time': 8.559999999999997, 'type': 'note_on', 'note': 60, 'velocity': 52}
# {'time': 8.559999999999997, 'type': 'note_on', 'note': 57, 'velocity': 48}
# {'time': 8.579999999999997, 'type': 'note_off', 'note': 60}
# {'time': 8.719999999999997, 'type': 'note_off', 'note': 57}
# {'time': 8.739999999999997, 'type': 'note_on', 'note': 63, 'velocity': 52}
# {'time': 8.739999999999997, 'type': 'note_on', 'note': 53, 'velocity': 44}
# {'time': 8.739999999999997, 'type': 'note_on', 'note': 60, 'velocity': 40}
# {'time': 8.899999999999997, 'type': 'note_off', 'note': 63}
# {'time': 8.899999999999997, 'type': 'note_off', 'note': 53}
# {'time': 8.899999999999997, 'type': 'note_off', 'note': 60}
# {'time': 8.899999999999997, 'type': 'note_on', 'note': 62, 'velocity': 52}
# {'time': 8.899999999999997, 'type': 'note_on', 'note': 55, 'velocity': 48}
# {'time': 8.899999999999997, 'type': 'note_on', 'note': 58, 'velocity': 44}
# {'time': 9.039999999999997, 'type': 'note_off', 'note': 58}
# {'time': 9.039999999999997, 'type': 'note_off', 'note': 62}
# {'time': 9.039999999999997, 'type': 'note_off', 'note': 55}
# {'time': 9.039999999999997, 'type': 'note_on', 'note': 53, 'velocity': 56}
# {'time': 9.039999999999997, 'type': 'pedal_on'}
# {'time': 9.239999999999997, 'type': 'note_on', 'note': 51, 'velocity': 56}
# {'time': 9.239999999999997, 'type': 'note_on', 'note': 70, 'velocity': 68}
# {'time': 9.239999999999997, 'type': 'note_off', 'note': 53}
# {'time': 9.239999999999997, 'type': 'note_on', 'note': 62, 'velocity': 44}

# %%
save_event_list_to_midi_file(event_list, 'sample.mid')
